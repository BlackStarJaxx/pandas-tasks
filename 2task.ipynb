# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline
from matplotlib import pyplot as plt
pd.set_option("display.precision", 2)
# pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
#Test
df = pd.read_csv("data/crime.csv")

# df.head()

# %%
#Task1

#1.1

df.shape
print(f'Кількість індексів == {len(df.index)}')
print(f'Кількість колонок == {len(df.columns)}')
# Out:
# Кількість індексів == 2116954
# Кількість колонок == 28

# %%
#1.2
# data_column = df.columns
# print(data_column, end = "/n")

#1.3
# data_type_column = df.dtypes
# df.info()
# print(data_type_column)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2116954 entries, 0 to 2116953
# Data columns (total 28 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   DR_NO           int64
#  1   Date Rptd       object
#  2   DATE OCC        object
#  3   TIME OCC        int64
#  4   AREA            int64
#  5   AREA NAME       object
#  6   Rpt Dist No     int64
#  7   Part 1-2        int64
#  8   Crm Cd          int64
#  9   Crm Cd Desc     object
#  10  Mocodes         object
#  11  Vict Age        int64
#  12  Vict Sex        object
#  13  Vict Descent    object
#  14  Premis Cd       float64
#  15  Premis Desc     object
#  16  Weapon Used Cd  float64
#  17  Weapon Desc     object
#  18  Status          object
#  19  Status Desc     object
#  20  Crm Cd 1        float64
#  21  Crm Cd 2        float64
#  22  Crm Cd 3        float64
#  23  Crm Cd 4        float64
#  24  LOCATION        object
#  25  Cross Street    object
#  26  LAT             float64
# ...

# %%
#1.4

# show = df.nunique()
# print(show)

# fill = df.fillna(method='ffill').sum()
# count_miss_fill = fill.count()
# print(count_miss_fill)
print(df.isna().sum())
# Out:
# DR_NO                   0
# Date Rptd               0
# DATE OCC                0
# TIME OCC                0
# AREA                    0
# AREA NAME               0
# Rpt Dist No             0
# Part 1-2                0
# Crm Cd                  0
# Crm Cd Desc             0
# Mocodes            228111
# Vict Age                0
# Vict Sex           196719
# Vict Descent       196765
# Premis Cd              53
# Premis Desc           187
# Weapon Used Cd    1405864
# Weapon Desc       1405865
# Status                  3
# Status Desc             0
# Crm Cd 1               10
# Crm Cd 2          1977178
# Crm Cd 3          2113439
# Crm Cd 4          2116850
# LOCATION                0
# Cross Street      1761493
# LAT                     0
# LON                     0
# dtype: int64

# %%
#2Task
#2.1 2.2
# stat = df.groupby(['Vict Sex'])[df['Vict Sex'] == 'F'].describe()
# print(stat)
group1 = df[df['Vict Sex'] == "F"]['Vict Age'].sum()
group2 = df[df['Vict Sex'] == "M"]['Vict Age'].sum()
if group1 > group2:
    print ('yes')
else:
    print(f'')
# Out:
# no

# %%
#2.3
# stat = df.groupby(['Status'], dropna=False)['Vict Age']
df['Vict Age'].hist()
# stat.hist()
# stat = df['Vict Age']
# df.plot.kde()
#
# Out:
# <AxesSubplot:>

# %%
# 2.4

# plt.title('Status influed from Age and Sex')
# plt.xlabel('Vict Age')
# plt.ylabel('Vict Sex')

# age = df.groupby(['Vict Sex' ])['Vict Age'].hist(figsize=(20,10))

# df['Vict Age'].hist(label='all')
df[df['Vict Sex'] == 'F']['Vict Age'].hist(color="yellow", 
                                             label='female', figsize=(20,10))
df[df['Vict Sex'] == 'M']['Vict Age'].hist(color="green", 
                                           label='male',figsize=(20,10))

plt.title('Distribution by class and gender.')
plt.xlabel('Age')
plt.ylabel('Sex')
plt.legend(loc='upper left');

# %%
#2.5

# df['Crm Cd Desc'].head(7).hist(figsize=(20,10))
df['Crm Cd Desc'].value_counts().head(10).plot(kind='barh', figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
#2.6

# desc = df.groupby(df['Vict Sex'] == 'F')['Crm Cd Desc'].head(2).hist(figsize=(20,10))

# df[df['Vict Sex'] == 'M']['Crm Cd Desc'].head(5).hist(color="green", 
#                                            label='Male',figsize=(50,10))
# df[df['Vict Sex'] == 'F']['Crm Cd Desc'].head(5).hist(color="yellow", 
#                                              label='Female', figsize=(30,11))
# s = df[df['Vict Sex'] == 'F']['Crm Cd Desc'].value_counts().head(3).plot(kind='barh',label='Female' ,  color='red', figsize=(20,10)) 
# d = df[df['Vict Sex'] == 'M']['Crm Cd Desc'].value_counts().head(3).plot(ax=s,kind='barh', label='Male' ,  color='blue', figsize=(20,10))

sns.countplot(x='Crm Cd Desc', hue='Vict Sex', data=df, order=df['Crm Cd Desc'].value_counts().iloc[:7].index);

# if male == female:
#     sex = ['F', 'M']
#     all_item = df['Crm Cd Desc'].all()
#     poor = df.loc[df['Vict Sex'].isin(sex), 'Crm Cd Desc'][df['Crm Cd Desc'] == all_item].head(5).hist(color="red", label='interception', figsize=(50,11))



plt.title('Distribution by crimea and gender.')
plt.xlabel('Crimea')
plt.ylabel('Status')
plt.legend(loc='best');

# %%
# 2.7

# df['Vict Descent'].hist(label='all')
df['Vict Descent'].value_counts().head(7).plot(kind="bar", figsize=(30,10))
# df['Vict Descent'].hist(color="yellow", 
#                                              label='female', figsize=(30,10))
plt.title('Distribution by class and gender.')
plt.xlabel('Descent')
plt.ylabel('Frequency')
plt.legend(loc='best');

# %%
#2.8
# data_area = df['AREA NAME'][df['Crm Cd']].value_counts()

area =  df['AREA NAME'].value_counts().head().plot(kind='bar')
# df['AREA NAME'].value_counts().tail().plot(kind='barh')

area
# crm = df['Crm Cd']
# cross = pd.crosstab(area, crm, dropna=True).head(3)
# cross
# print(data_area)
# Out:
# <AxesSubplot:>

# %%
#2.8.2
area =  df['AREA NAME'].value_counts().head(20).plot(kind='bar')

# %%
 #2.9
descent = df['AREA NAME'].all()
# print (descent)
data = df[df['AREA NAME'] == '77th']['Vict Descent'].head(5).hist(color="green", 
                                           label=descent, figsize=(30,10))
# data = df.groupby([df['Vict Descent'].isin([descent]), 'AREA NAME'])['AREA NAME'].head(1).plot(kind='bar', color="red", 
#                                            label='1', figsize=(30,10))
# data = df.groupby([df['Vict Descent'].isin([descent]), 'AREA NAME'])['AREA NAME'].head(1).plot(kind='bar', color="yellow", 
#                                            label='2', figsize=(30,10))

plt.title('Distribution by region and descent.')
plt.xlabel('Region')
plt.ylabel('Frequency')
plt.legend(loc='best');

# %%
# area =  df['AREA NAME']
# des = df['Vict Descent'].value_counts()

# df['AREA NAME'].head(5).hist()
# df['Vict Descent'].value_counts()
df.groupby(df['Vict Descent']== 'W')['AREA NAME'].hist(figsize=(40,10), color='red', label='W')
df.groupby(df['Vict Descent']== 'B')['AREA NAME'].hist(figsize=(40,10), color='green',label='B')
df.groupby(df['Vict Descent']== 'H')['AREA NAME'].hist(figsize=(40,10), color='blue', label='Hispanic')


# df.groupby(df['Vict Descent']== 'O')['AREA NAME'].head(5).hist(figsize=(40,10), color='orange', label='O')

plt.title('Distribution by region and descent.')
plt.xlabel('Region')
plt.ylabel('Descent')
plt.legend(loc='best');

# %%
#3Task
#3.1
df['DATE OCC'].head(3).hist()
# Out:
# <AxesSubplot:>

# %%
#3.2 3.3

# df.groupby(df['DATE OCC'].dt.day)

dat = df['DATE OCC']
data = pd.to_datetime(dat, format='%m/%d/%Y %H:%M:%S AM')
data.dt.weekday.head(365).plot()
# Out:
# <AxesSubplot:>

# %%
#3.4
df.groupby(df['Vict Sex']== 'F')['DATE OCC'].head(5).hist(figsize=(40,10), color='red', label='Women')
df.groupby(df['Vict Sex']== 'M')['DATE OCC'].head(5).hist(figsize=(40,10), color='blue', label='Men')
# Out:
# <AxesSubplot:>

# %%
#3.6

dat = df['DATE OCC']
data = pd.to_datetime(dat, format='%m/%d/%Y %H:%M:%S AM')
date = data.dt.weekday
date.head()
# crm = df['Vict Age'][date].head(15)
# crm.max()
pd.crosstab(crm, data, dropna=True).head(20).plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-47c623768576> in <module>
#       7 # crm = df['Vict Age'][date].head(15)
#       8 # crm.max()
# ----> 9 pd.crosstab(crm, data, dropna=True).head(20).plot()
#      10
#      11
#
# /usr/local/lib/python3.9/site-packages/pandas/core/reshape/pivot.py in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     596         **dict(zip(unique_colnames, columns)),
#     597     }
# --> 598     df = DataFrame(data, index=common_idx)
#     599     original_df_cols = df.columns
#     600
#
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
# ...
